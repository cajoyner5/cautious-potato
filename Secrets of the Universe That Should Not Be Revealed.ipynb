# %% [markdown]
# # This is a Heading
# * This is a sub-title
# *This is another bullet
#
# Texty text is here

# %%
#This is a Headinh
* Sub title
* bullet point

words are the secrets
# Out:
#   File "<ipython-input-1-21d0703610a2>", line 2
#     * Sub title
#               ^
# SyntaxError: invalid syntax

# %%
# This is a Heading

# %% [markdown]
# # Heading
# * point
# * point 2
#
# Secrets

# %%
print ("Chloe has many secrets that should not be revealed.")
# Out:
# Chloe has many secrets that should not be revealed.
